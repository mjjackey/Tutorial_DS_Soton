# %% [markdown]
# **Contents:**
#
# Numpy, scipy, matplotlib
#
# Mathematical operations using Numpy and scipy
#
# Plotting graphs with matplotlib

# %% [markdown]
# **Example** (note you need to run this example so that numpy and matplotlib are imported):

# %%
import numpy as np # This statement imports the numpy package, I have called it np, as a shorthand
import matplotlib.pyplot as plt

# %% [markdown]
# **Matplotlib**
#
# Matplotlib is a plotting library for python that produces figures in a variety of formats.
#
#
# **Example:**

# %%
n,xmin,xmax=10,1,100
x=np.linspace(xmin,xmax,n)
y=np.linspace(xmin,xmax,n)+np.random.normal(loc=0,scale=8,size=n)

plt.figure(1)
plt.plot(x,y,'kx')
plt.plot(x,x,'b--')
plt.xlabel('x value')
plt.ylabel('y value')
plt.show()

# %% [markdown]
# **Exercise:** Work out how the previous plot was made, copy the code to the cell below this one and play around with it. Alter the colours of the lines, add in new lines, change the thicknesses of the line, change the marker type.

# %%
n,xmin,xmax=10,1,100
x=np.linspace(xmin,xmax,n)
#y=np.linspace(xmin,xmax,n)+np.random.normal(loc=0,scale=8,size=n)
y=x+np.random.normal(loc=0,scale=8,size=n)

plt.figure(1)
plt.plot(x,y,'kx')
plt.plot(x,x,'r*')
plt.xlabel('x value')
plt.ylabel('y value')
plt.show()

# %% [markdown]
# **Exercise:** Create your own random data using np.random and plot your own results. Create a quadratic, cubic and quartic plots. Create a 2-d array with, say, 30 by 30 elements (use np.random.uniform) and plot a image (use plt.imshow) of the array.

# %%
def f1(x, m, c): # y = m*x^2 + c (ground truth function)
    return m*pow(x,2) + c 
def f2(x, m, c): # y = m*x^3+ c (ground truth function)
    return m*pow(x,3) + c 
def f3(x, m, c): # y = m*x^4 + c (ground truth function)
    return m*pow(x,4) + c 

n,xmin,xmax=10,1,100
x=np.linspace(xmin,xmax,n)
y1 = f1(x, 3., 9.) + np.random.normal(0,scale=4, size=np.shape(x))
y2 = f2(x, 3., 9.) + np.random.normal(0,scale=4, size=np.shape(x))
y3 = f3(x, 3., 9.) + np.random.normal(0,scale=4, size=np.shape(x))

plt.figure(1)
plt.plot(x,y1,'kx')
plt.plot(x,x,'r*')
plt.xlabel('x value')
plt.ylabel('y value')
plt.show()

plt.figure(2)
plt.scatter(x, y1, marker='o', c='k')  #draw 散点图
plt.figure(3)
plt.scatter(x, y2, marker='*', c='k')  #draw 散点图
plt.figure(4)
plt.scatter(x, y3, marker='x', c='k')  #draw 散点图

# %% [markdown]
# **Exercise:** Create a large (~10<sup>3</sup>) sample of random data and plot it in a histogram (using plt.hist).
# Play around with the bins of the histogram and plot the results.
